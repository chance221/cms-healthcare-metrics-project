# %%
import pandas as pd
import streamlit as st
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "local")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["readmission_vs_staffing.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)

#df.head(10)


# Filter out any rows where readmission_rssr_upper_ci - readmission_rssr_lower_ci is greater than 6
#ci_width = df["readmission_rsrr_upper_ci"] - df["readmission_rsrr_lower_ci"]
#reliable_df = df[ci_width < 8]

#print(len(reliable_df))
#print(len(df))
#return a count of how many rows are in the dataframe
#print(f"Number of rows in the dataframe: {len(df1)}")
# Out:
# Index(['ccn', 'measurement_period', 'start_date', 'end_date',
#        'readmission_number', 'readmission_volume', 'readmission_obs_rate',
#        'readmission_rsrr', 'readmission_rsrr_lower_ci',
#        'readmission_rsrr_upper_ci', 'readmission_comp_perf',
#        'readmission_national_unadjusted_avg', 'avg_daily_rn_hours',
#        'avg_weekday_rn_hours', 'avg_weekend_rn_hours',
#        'avg_weekday_rn_staff_hours', 'avg_weekend_rn_staff_hours',
#        'avg_weekday_rn_admin_hours', 'avg_weekend_rn_admin_hours',
#        'avg_weekday_rn_director_of_nursing_hours',
#        'avg_weekend_rn_director_of_nursing_hours', 'avg_daily_lpn_hours',
#        'avg_weekday_lpn_hours', 'avg_weekend_lpn_hours',
#        'avg_weekday_lpn_staff_hours', 'avg_weekend_lpn_staff_hours',
#        'avg_weekday_lpn_admin_hours', 'avg_weekend_lpn_admin_hours',
#        'avg_daily_cna_hours', 'avg_weekday_cna_hours', 'avg_weekend_cna_hours',
# ...

# %%
import pandas as pd
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "local")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["dtc_vs_staffing.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)

df.head(10)
# Out:
#       ccn measurement_period  start_date    end_date  dtc_number  dtc_volume  \
# 0  015133             2023Q3  10/01/2021  09/30/2023        42.0        99.0
# 1  015193             2023Q3  10/01/2021  09/30/2023        36.0        74.0
# 2  015214             2023Q3  10/01/2021  09/30/2023        10.0        31.0
# 3  015321             2023Q3  10/01/2021  09/30/2023        11.0        39.0
# 4  015391             2023Q3  10/01/2021  09/30/2023        89.0       203.0
# 5  035095             2023Q3  10/01/2021  09/30/2023        43.0        73.0
# 6  035193             2023Q3  10/01/2021  09/30/2023        17.0        46.0
# 7  035280             2023Q3  10/01/2021  09/30/2023       504.0       747.0
# 8  045070             2023Q3  10/01/2021  09/30/2023        25.0        81.0
# 9  045183             2023Q3  10/01/2021  09/30/2023        77.0       149.0
#
#    dtc_obs_rate  dtc_rs_rate  dtc_rs_rate_lower_ci  dtc_rs_rate_upper_ci  ...  \
# ...

# %%
import pandas as pd
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "local")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["falls_vs_staffing.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)


df[["ccn", "measurement_period", "rn_hours_per_resident_day"]].head(10)

#df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 15
#      11 path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
#      12 df = pd.read_parquet(path)
# ---> 15 df[["ccn", "measurement_period", "rn_hours_per_resident_day", "dtc_rs_rate"]].head(10)
#      17 #df.head(10)
#
# File c:\Python313\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Python313\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
# ...

# %%
import pandas as pd
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "local")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["hai_vs_staffing.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)

df.head(10)
# Out:
#       ccn measurement_period  start_date    end_date  hai_number  hai_volume  \
# 0  015063             2023Q3  10/01/2022  09/30/2023         3.0        79.0
# 1  015067             2023Q3  10/01/2022  09/30/2023         5.0        96.0
# 2  015196             2023Q3  10/01/2022  09/30/2023         3.0        37.0
# 3  015414             2023Q3  10/01/2022  09/30/2023         NaN        10.0
# 4  015420             2023Q3  10/01/2022  09/30/2023         3.0        66.0
# 5  015422             2023Q3  10/01/2022  09/30/2023         7.0       101.0
# 6  015426             2023Q3  10/01/2022  09/30/2023         5.0       144.0
# 7  025025             2023Q3  10/01/2022  09/30/2023         7.0       143.0
# 8  035014             2023Q3  10/01/2022  09/30/2023         2.0        57.0
# 9  035087             2023Q3  10/01/2022  09/30/2023         NaN        22.0
#
#    hai_obs_rate  hai_rs_rate  hai_rs_rate_lower_ci  hai_rs_rate_upper_ci  ...  \
# ...

# %%
import pandas as pd
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "local")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["pressure_ulcer_vs_staffing.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)

df.head(10)
# Out:
#       ccn measurement_period  start_date    end_date  \
# 0  015019             2023Q4  01/01/2023  12/31/2023
# 1  015035             2023Q4  01/01/2023  12/31/2023
# 2  015163             2023Q4  01/01/2023  12/31/2023
# 3  015166             2023Q4  01/01/2023  12/31/2023
# 4  015176             2023Q4  01/01/2023  12/31/2023
# 5  015194             2023Q4  01/01/2023  12/31/2023
# 6  015217             2023Q4  01/01/2023  12/31/2023
# 7  015222             2023Q4  01/01/2023  12/31/2023
# 8  015425             2023Q4  01/01/2023  12/31/2023
# 9  015452             2023Q4  01/01/2023  12/31/2023
#
#    pressure_ulcer_numerator  pressure_ulcer_denominator  \
# 0                       2.0                        48.0
# 1                       6.0                        66.0
# 2                       1.0                       183.0
# 3                       0.0                        28.0
# 4                       0.0                        53.0
# ...

# %%
import pandas as pd
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "dev")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["facility_staffing_by_quarter.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)

df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Python313\Lib\site-packages\fsspec\registry.py:268, in get_filesystem_class(protocol)
#     267 try:
# --> 268     register_implementation(protocol, _import_class(bit["class"]))
#     269 except ImportError as e:
#
# File c:\Python313\Lib\site-packages\fsspec\registry.py:303, in _import_class(fqp)
#     302 is_s3 = mod == "s3fs"
# --> 303 mod = importlib.import_module(mod)
#     304 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File C:\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# ...

# %%
import pandas as pd
from pyspark_jobs.common.config_loader import load_all_environment_configs, load_all_gold_configs
from pyspark_jobs.common.io_utils import resolve_path

env_configs, _ = load_all_environment_configs()
env_config = next(c for c in env_configs.values() if c.env == "dev")

gold_configs, _ = load_all_gold_configs()
gold_config = gold_configs["falls_vs_staffing.yaml"]

path = resolve_path(env_config, gold_config.output_path.format(env=env_config.env))
df = pd.read_parquet(path)

df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Python313\Lib\site-packages\fsspec\registry.py:268, in get_filesystem_class(protocol)
#     267 try:
# --> 268     register_implementation(protocol, _import_class(bit["class"]))
#     269 except ImportError as e:
#
# File c:\Python313\Lib\site-packages\fsspec\registry.py:303, in _import_class(fqp)
#     302 is_s3 = mod == "s3fs"
# --> 303 mod = importlib.import_module(mod)
#     304 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File C:\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# ...
